# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bedrooms = np.array([1,1,2,2,3,4,4,5,5,5])
house_prise = np.array([15000, 18000, 27000, 34000, 50000, 68000, 65000, 81000,85000, 90000])
bedrooms
# Out:
# array([1, 1, 2, 2, 3, 4, 4, 5, 5, 5])

# %%
    # menampilkan scatter plot dari dataset
    # %matplotlib inline
    plt.scatter(bedrooms, house_price)

# %% [markdown]
# #### Scatter plot

# %%
# %matplotlib inline
plt.scatter(bedrooms, house_prise)

# %%
    from sklearn.linear_model import LinearRegression
    bedrooms = bedrooms.reshape(-1, 1)
    linreg = LinearRegression()
    linreg.fit(bedrooms, house_price)

# %%
from sklearn.linear_model import LinearRegression

# %%
bedrooms_s = bedrooms.reshape(-1, 1)
bedrooms_s
# Out:
# array([[1],
#        [1],
#        [2],
#        [2],
#        [3],
#        [4],
#        [4],
#        [5],
#        [5],
#        [5]])

# %%
linreg = LinearRegression()
linreg.fit(bedrooms_s, house_prise)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(bedrooms, house_prise)
#tambah garis
plt.plot(bedrooms, linreg.predict(bedrooms_s))
